# %% [markdown]
# # Pandas - Working with Time Series Date Data

# %%
import pandas as pd
from datetime import datetime
import numpy as np
df = pd.date_range(start = '11/01/2019', end = '11/07/2019', freq = 'H')
df
# Out:
# DatetimeIndex(['2019-11-01 00:00:00', '2019-11-01 01:00:00',
#                '2019-11-01 02:00:00', '2019-11-01 03:00:00',
#                '2019-11-01 04:00:00', '2019-11-01 05:00:00',
#                '2019-11-01 06:00:00', '2019-11-01 07:00:00',
#                '2019-11-01 08:00:00', '2019-11-01 09:00:00',
#                ...
#                '2019-11-06 15:00:00', '2019-11-06 16:00:00',
#                '2019-11-06 17:00:00', '2019-11-06 18:00:00',
#                '2019-11-06 19:00:00', '2019-11-06 20:00:00',
#                '2019-11-06 21:00:00', '2019-11-06 22:00:00',
#                '2019-11-06 23:00:00', '2019-11-07 00:00:00'],
#               dtype='datetime64[ns]', length=145, freq='H')

# %% [markdown]
# **NOTE ISO 8601 format**
# -  yyyy-mm-dd hh:mm:ss

# %%
len(df)
# Out:
# 145

# %%
df = pd.DataFrame(df, columns = ['date'])
df['sales'] = np.random.randint(0, 1000, size = len(df))
df.head()
# Out:
#                  date  sales
# 0 2019-11-01 00:00:00    725
# 1 2019-11-01 01:00:00    346
# 2 2019-11-01 02:00:00    559
# 3 2019-11-01 03:00:00    172
# 4 2019-11-01 04:00:00    347

# %% [markdown]
# # Selecting using dates

# %%
df = df.set_index('date')
df.head()
# Out:
#                      sales
# date
# 2019-11-01 00:00:00    725
# 2019-11-01 01:00:00    346
# 2019-11-01 02:00:00    559
# 2019-11-01 03:00:00    172
# 2019-11-01 04:00:00    347

# %% [markdown]
# ## Using .loc[] to index specific dates

# %%
df.loc['2019-11-01 03:00:00', 'sales']
# Out:
# 184

# %%
df.loc['2019-11-01 03:00:00']
# Out:
# sales    184
# Name: 2019-11-01 03:00:00, dtype: int64

# %%
df.loc['2019-11-01']
# Out:
#                      sales
# date
# 2019-11-01 00:00:00     33
# 2019-11-01 01:00:00    983
# 2019-11-01 02:00:00    389
# 2019-11-01 03:00:00    184
# 2019-11-01 04:00:00    852
# 2019-11-01 05:00:00    664
# 2019-11-01 06:00:00    328
# 2019-11-01 07:00:00    994
# 2019-11-01 08:00:00    787
# 2019-11-01 09:00:00    447
# 2019-11-01 10:00:00    925
# 2019-11-01 11:00:00    367
# 2019-11-01 12:00:00    165
# 2019-11-01 13:00:00    765
# 2019-11-01 14:00:00    417
# 2019-11-01 15:00:00    452
# 2019-11-01 16:00:00    496
# 2019-11-01 17:00:00    648
# 2019-11-01 18:00:00    355
# 2019-11-01 19:00:00    624
# 2019-11-01 20:00:00    212
# 2019-11-01 21:00:00    309
# 2019-11-01 22:00:00    698
# 2019-11-01 23:00:00    852

# %%
df.loc['2019-11-01' : '2019-11-02']
# Out:
#                      sales
# date
# 2019-11-01 00:00:00     33
# 2019-11-01 01:00:00    983
# 2019-11-01 02:00:00    389
# 2019-11-01 03:00:00    184
# 2019-11-01 04:00:00    852
# 2019-11-01 05:00:00    664
# 2019-11-01 06:00:00    328
# 2019-11-01 07:00:00    994
# 2019-11-01 08:00:00    787
# 2019-11-01 09:00:00    447
# 2019-11-01 10:00:00    925
# 2019-11-01 11:00:00    367
# 2019-11-01 12:00:00    165
# 2019-11-01 13:00:00    765
# 2019-11-01 14:00:00    417
# 2019-11-01 15:00:00    452
# 2019-11-01 16:00:00    496
# 2019-11-01 17:00:00    648
# 2019-11-01 18:00:00    355
# 2019-11-01 19:00:00    624
# 2019-11-01 20:00:00    212
# 2019-11-01 21:00:00    309
# 2019-11-01 22:00:00    698
# 2019-11-01 23:00:00    852
# 2019-11-02 00:00:00    527
# 2019-11-02 01:00:00    127
# 2019-11-02 02:00:00    270
# 2019-11-02 03:00:00    695
# 2019-11-02 04:00:00    133
# 2019-11-02 05:00:00    225
# 2019-11-02 06:00:00    592
# 2019-11-02 07:00:00     52
# 2019-11-02 08:00:00    519
# 2019-11-02 09:00:00    141
# 2019-11-02 10:00:00    193
# 2019-11-02 11:00:00    713
# 2019-11-02 12:00:00    847
# 2019-11-02 13:00:00    857
# 2019-11-02 14:00:00    846
# 2019-11-02 15:00:00    352
# 2019-11-02 16:00:00    425
# 2019-11-02 17:00:00    568
# 2019-11-02 18:00:00    357
# 2019-11-02 19:00:00    299
# 2019-11-02 20:00:00    798
# 2019-11-02 21:00:00    177
# 2019-11-02 22:00:00    484
# 2019-11-02 23:00:00    294

# %% [markdown]
# # Resampling
#
# **Summary States** - we can use Statistical methods over different time intervals
# - mean(), sum(), count(), min(), max()
#
# **Down-sampling**
# - reduce datetime rows to longer frequency
#
# **Up-sampling**
# - increase datetime rows to shorter frequency

# %%
df.resample('D').mean()
# df.resample('D').sum()
# Out:
#             sales
# date
# 2019-11-01  12946
# 2019-11-02  10491
# 2019-11-03  13192
# 2019-11-04  12193
# 2019-11-05  10732
# 2019-11-06  13524
# 2019-11-07    574

# %%
df.resample('T').mean()
# Out:
#                      sales
# date
# 2019-11-01 00:00:00  725.0
# 2019-11-01 00:01:00    NaN
# 2019-11-01 00:02:00    NaN
# 2019-11-01 00:03:00    NaN
# 2019-11-01 00:04:00    NaN
# ...                    ...
# 2019-11-06 23:56:00    NaN
# 2019-11-06 23:57:00    NaN
# 2019-11-06 23:58:00    NaN
# 2019-11-06 23:59:00    NaN
# 2019-11-07 00:00:00  152.0
#
# [8641 rows x 1 columns]

# %% [markdown]
# ## Resampling frequencies
#
# - 'min', 'T' - minute
# - ‘H’ - hour
# - ‘D’ - day
# - ‘B’ - business day
# - ‘W’ - week
# - ‘M’ - month
# - ‘Q’ - quarter
# - ‘A’ - year

# %% [markdown]
# # Parsing dates

# %%
df = pd.DataFrame({'year' : [2015, 2016],
                   'month': [2, 3],
                  'day': [4, 5]})
df
# Out:
#    year  month  day
# 0  2015      2    4
# 1  2016      3    5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    2 non-null      int64
#  1   month   2 non-null      int64
#  2   day     2 non-null      int64
# dtypes: int64(3)
# memory usage: 176.0 bytes

# %%
pd.to_datetime(df)
# Out:
# 0   2015-02-04
# 1   2016-03-05
# dtype: datetime64[ns]

# %%
pd.to_datetime('2019-01-01', format = '%Y-%m-%d', errors = 'ignore')
# Out:
# Timestamp('2019-01-01 00:00:00')
